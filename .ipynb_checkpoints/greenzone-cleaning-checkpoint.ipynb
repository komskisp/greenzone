# %%
import pandas as pd
#https://ucr.fbi.gov/crime-in-the-u.s/2019/crime-in-the-u.s.-2019/topic-pages/tables/table-8/table-8.xls/view

# %%
read_file = pd.read_excel (r'/Users/pauliuskomskis/Downloads/wyoming.xls')
read_file.to_csv (r'/Users/pauliuskomskis/Desktop/github/greenzone/data/2019/wyoming.csv')
df = pd.read_csv('/Users/pauliuskomskis/Desktop/github/greenzone/data/2019/wyoming.csv')
print('Excel to CSV conversion Success')
df
df.columns = df.iloc[3] # taking 3rd row and making it column headers
df.drop(df.index[3]) # deleting the 3rd row from df
df = df.dropna() # dropping NaN value rows/data
df.drop(df.iloc[:,:1], inplace = True, axis = 1) # droping the firs row as it is a duplicate of headers
df.set_index('City')
df = df.drop(df.index[0]) # dropping a duplicate column
df.reset_index(drop=True)
# Out:
# Excel to CSV conversion Success
# 3           City Population Violent\ncrime  \
# 0          Afton       2017              0
# 1        Buffalo       4571              8
# 2         Casper      57752            169
# 3       Cheyenne      64501            220
# 4          Cody2       9865             17
# 5   Diamondville        756              1
# 6        Douglas       6294              8
# 7      Evanston2      11624             29
# 8     Evansville       2977              7
# 9       Gillette      31960             43
# 10      Glenrock       2544              3
# 11   Green River      11927             22
# 12      Greybull       1857              0
# 13         Hanna        766              0
# 14      Kemmerer       2745              1
# 15        Lander       7489              0
# 16       Laramie      32669             58
# 17          Lusk       1537              5
# 18         Mills       3975              3
# 19     Moorcroft       1068              1
# ...

# %%
df
# Out:
# 3           City Population Violent\ncrime  \
# 4          Afton       2017              0
# 5        Buffalo       4571              8
# 6         Casper      57752            169
# 7       Cheyenne      64501            220
# 8          Cody2       9865             17
# 9   Diamondville        756              1
# 10       Douglas       6294              8
# 11     Evanston2      11624             29
# 12    Evansville       2977              7
# 13      Gillette      31960             43
# 14      Glenrock       2544              3
# 15   Green River      11927             22
# 16      Greybull       1857              0
# 17         Hanna        766              0
# 18      Kemmerer       2745              1
# 19        Lander       7489              0
# 20       Laramie      32669             58
# 21          Lusk       1537              5
# 22         Mills       3975              3
# 23     Moorcroft       1068              1
# 24     Newcastle       3386             10
# ...

# %%
df.columns
# Out:
# Index(['City', 'Population', 'Violent\ncrime',
#        'Murder and\nnonnegligent\nmanslaughter', 'Rape1', 'Robbery',
#        'Aggravated\nassault', 'Property\ncrime', 'Burglary', 'Larceny-\ntheft',
#        'Motor\nvehicle\ntheft', 'Arson'],
#       dtype='object', name=3)

# %%
df.rename(columns={'City': 'city',
                  'Population': 'population',
                  'Violent\ncrime': 'violent_crime',
                  'Murder and\nnonnegligent\nmanslaughter': 'murder',
                  'Rape1': 'rape',
                  'Robbery': 'robbery',
                  'Aggravated\nassault': 'assault',
                  'Property\ncrime': 'property_crime',
                  'Burglary': 'burglary',
                  'Larceny-\ntheft': 'larceny',
                  'Motor\nvehicle\ntheft': 'gta',
                  'Arson': 'arson'}, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
# 3           city population violent_crime murder rape robbery assault  \
# 0          Afton       2017             0      0    0       0       0
# 1        Buffalo       4571             8      0    1       0       7
# 2         Casper      57752           169      2   58      18      91
# 3       Cheyenne      64501           220      5   43      27     145
# 4          Cody2       9865            17      0    7       1       9
# 5   Diamondville        756             1      0    0       0       1
# 6        Douglas       6294             8      1    0       1       6
# 7      Evanston2      11624            29      0   21       1       7
# 8     Evansville       2977             7      0    0       3       4
# 9       Gillette      31960            43      1    9       0      33
# 10      Glenrock       2544             3      0    0       0       3
# 11   Green River      11927            22      0    0       0      22
# ...

# %%
# df['city'].replace(['Aitkin3'], 'Aitkin', inplace=True)

# %%
df.to_csv('/Users/pauliuskomskis/Desktop/github/greenzone/data/2019/wyoming-clean.csv')
